# %%
# General imports
import numpy as np
import pandas as pd
import os, sys, gc, warnings, random

from sklearn import metrics
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import LabelEncoder

from tqdm import tqdm

import math
warnings.filterwarnings('ignore')

# %%
########################### Helpers
#################################################################################
## -------------------
## Seeder
# :seed to make all processes deterministic     # type: int
def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
## -------------------

# %%
########################### Vars
#################################################################################
SEED = 42
seed_everything(SEED)
LOCAL_TEST = False
TARGET = 'isFraud'

# %%
########################### DATA LOAD
#################################################################################
print('Load Data')
train_df = pd.read_pickle('../input/ieee-data-minification/train_transaction.pkl')

if LOCAL_TEST:
    test_df = train_df.iloc[-100000:,].reset_index(drop=True)
    train_df = train_df.iloc[:400000,].reset_index(drop=True)
    
    train_identity = pd.read_pickle('../input/ieee-data-minification/train_identity.pkl')
    test_identity  = train_identity[train_identity['TransactionID'].isin(test_df['TransactionID'])].reset_index(drop=True)
    train_identity = train_identity[train_identity['TransactionID'].isin(train_df['TransactionID'])].reset_index(drop=True)
else:
    test_df = pd.read_pickle('../input/ieee-data-minification/test_transaction.pkl')
    test_identity = pd.read_pickle('../input/ieee-data-minification/test_identity.pkl')
# Out:
# Load Data

# %%
########################### Reset values for "noise" card1
valid_card = train_df['card1'].value_counts()
valid_card = valid_card[valid_card>10]
valid_card = list(valid_card.index)
    
train_df['card1'] = np.where(train_df['card1'].isin(valid_card), train_df['card1'], np.nan)
test_df['card1']  = np.where(test_df['card1'].isin(valid_card), test_df['card1'], np.nan)

# %%
########################### Freq encoding
i_cols = ['card1','card2','card3','card5',
          'C1','C2','C3','C4','C5','C6','C7','C8','C9','C10','C11','C12','C13','C14',
          'D1','D2','D3','D4','D5','D6','D7','D8','D9',
          'addr1','addr2',
          'dist1','dist2',
          'P_emaildomain', 'R_emaildomain'
         ]

for col in i_cols:
    temp_df = pd.concat([train_df[[col]], test_df[[col]]])
    fq_encode = temp_df[col].value_counts().to_dict()   
    train_df[col+'_fq_enc'] = train_df[col].map(fq_encode)
    test_df[col+'_fq_enc']  = test_df[col].map(fq_encode)

# %%
########################### ProductCD and M4 Target mean
for col in ['ProductCD','M4']:
    temp_dict = train_df.groupby([col])[TARGET].agg(['mean']).reset_index().rename(
                                                        columns={'mean': col+'_target_mean'})
    temp_dict.index = temp_dict[col].values
    temp_dict = temp_dict[col+'_target_mean'].to_dict()

    train_df[col+'_target_mean'] = train_df[col].map(temp_dict)
    test_df[col+'_target_mean']  = test_df[col].map(temp_dict)

# %%
########################### Encode Str columns
for col in list(train_df):
    if train_df[col].dtype=='O':
        print(col)
        train_df[col] = train_df[col].fillna('unseen_before_label')
        test_df[col]  = test_df[col].fillna('unseen_before_label')
        
        train_df[col] = train_df[col].astype(str)
        test_df[col] = test_df[col].astype(str)
        
        le = LabelEncoder()
        le.fit(list(train_df[col])+list(test_df[col]))
        train_df[col] = le.transform(train_df[col])
        test_df[col]  = le.transform(test_df[col])
        
        train_df[col] = train_df[col].astype('category')
        test_df[col] = test_df[col].astype('category')
# Out:
# P_emaildomain
# R_emaildomain

# %%
########################### Model Features 
## We can use set().difference() but order matters
rm_cols = [
    'TransactionID','TransactionDT',TARGET,
]
features_columns = list(train_df)
for col in rm_cols:
    if col in features_columns:
        features_columns.remove(col)

# %%
########################### Model params
lgb_params = {
                    'objective':'binary',
                    'boosting_type':'gbdt',
                    'metric':'auc',
                    'n_jobs':-1,
                    'learning_rate':0.01,
                    'num_leaves': 2**8,
                    'max_depth':-1,
                    'tree_learner':'serial',
                    'colsample_bytree': 0.7,
                    'subsample_freq':1,
                    'subsample':1,
                    'n_estimators':800,
                    'max_bin':255,
                    'verbose':-1,
                    'seed': SEED,
                    'early_stopping_rounds':100, 
                }

# %%
########################### Model
import lightgbm as lgb

def make_predictions(tr_df, tt_df, features_columns, target, lgb_params, NFOLDS=2):
    folds = KFold(n_splits=NFOLDS, shuffle=False, random_state=SEED)

    X,y = tr_df[features_columns], tr_df[target]    
    P,P_y = tt_df[features_columns], tt_df[target]  

    tt_df = tt_df[['TransactionID',target]]    
    predictions = np.zeros(len(tt_df))
    
    for fold_, (trn_idx, val_idx) in enumerate(folds.split(X, y)):
        print('Fold:',fold_)
        tr_x, tr_y = X.iloc[trn_idx,:], y[trn_idx]
        vl_x, vl_y = X.iloc[val_idx,:], y[val_idx]
            
        print(len(tr_x),len(vl_x))
        tr_data = lgb.Dataset(tr_x, label=tr_y)

        if LOCAL_TEST:
            vl_data = lgb.Dataset(P, label=P_y) 
        else:
            vl_data = lgb.Dataset(vl_x, label=vl_y)  

        estimator = lgb.train(
            lgb_params,
            tr_data,
            valid_sets = [tr_data, vl_data],
            verbose_eval = 200,
        )   
        
        pp_p = estimator.predict(P)
        predictions += pp_p/NFOLDS

        if LOCAL_TEST:
            feature_imp = pd.DataFrame(sorted(zip(estimator.feature_importance(),X.columns)), columns=['Value','Feature'])
            print(feature_imp)
        
        del tr_x, tr_y, vl_x, vl_y, tr_data, vl_data
        gc.collect()
        
    tt_df['prediction']  = predictions
    
    return tt_df
## -------------------

# %%
########################### Model Train
if LOCAL_TEST:
    test_predictions = make_predictions(train_df, test_df, features_columns, TARGET, lgb_params)
    print(metrics.roc_auc_score(test_predictions[TARGET], test_predictions['prediction']))
else:
    lgb_params['learning_rate'] = 0.005
    lgb_params['n_estimators'] = 2000
    lgb_params['early_stopping_rounds'] = 100    
    test_predictions = make_predictions(train_df, test_df, features_columns, TARGET, lgb_params, NFOLDS=10)
# Out:
# Fold: 0
# 531486 59054
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.931554	valid_1's auc: 0.891085
# [400]	training's auc: 0.956259	valid_1's auc: 0.903635
# [600]	training's auc: 0.971668	valid_1's auc: 0.91294
# [800]	training's auc: 0.980941	valid_1's auc: 0.919384
# [1000]	training's auc: 0.986448	valid_1's auc: 0.922966
# [1200]	training's auc: 0.990202	valid_1's auc: 0.925279
# [1400]	training's auc: 0.992619	valid_1's auc: 0.926284
# [1600]	training's auc: 0.99424	valid_1's auc: 0.927073
# [1800]	training's auc: 0.995353	valid_1's auc: 0.92729
# Early stopping, best iteration is:
# [1898]	training's auc: 0.995791	valid_1's auc: 0.927469
# Fold: 1
# 531486 59054
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.930439	valid_1's auc: 0.888982
# [400]	training's auc: 0.955809	valid_1's auc: 0.901493
# [600]	training's auc: 0.971262	valid_1's auc: 0.910191
# [800]	training's auc: 0.980877	valid_1's auc: 0.918272
# [1000]	training's auc: 0.986519	valid_1's auc: 0.923406
# [1200]	training's auc: 0.990183	valid_1's auc: 0.92633
# [1400]	training's auc: 0.992579	valid_1's auc: 0.928451
# [1600]	training's auc: 0.994166	valid_1's auc: 0.929774
# [1800]	training's auc: 0.995331	valid_1's auc: 0.930602
# [2000]	training's auc: 0.996156	valid_1's auc: 0.931316
# Did not meet early stopping. Best iteration is:
# [2000]	training's auc: 0.996156	valid_1's auc: 0.931316
# Fold: 2
# 531486 59054
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.931424	valid_1's auc: 0.897073
# [400]	training's auc: 0.954974	valid_1's auc: 0.915907
# [600]	training's auc: 0.97134	valid_1's auc: 0.931149
# [800]	training's auc: 0.981127	valid_1's auc: 0.939936
# [1000]	training's auc: 0.986849	valid_1's auc: 0.944864
# [1200]	training's auc: 0.990609	valid_1's auc: 0.947898
# [1400]	training's auc: 0.992961	valid_1's auc: 0.950063
# [1600]	training's auc: 0.99452	valid_1's auc: 0.951455
# [1800]	training's auc: 0.995571	valid_1's auc: 0.952421
# [2000]	training's auc: 0.996357	valid_1's auc: 0.953146
# Did not meet early stopping. Best iteration is:
# [2000]	training's auc: 0.996357	valid_1's auc: 0.953146
# Fold: 3
# 531486 59054
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.929636	valid_1's auc: 0.90855
# [400]	training's auc: 0.954918	valid_1's auc: 0.926651
# [600]	training's auc: 0.971355	valid_1's auc: 0.938692
# [800]	training's auc: 0.980882	valid_1's auc: 0.944425
# [1000]	training's auc: 0.986762	valid_1's auc: 0.947583
# [1200]	training's auc: 0.990632	valid_1's auc: 0.949353
# [1400]	training's auc: 0.993023	valid_1's auc: 0.9506
# [1600]	training's auc: 0.994605	valid_1's auc: 0.951532
# [1800]	training's auc: 0.995715	valid_1's auc: 0.952116
# [2000]	training's auc: 0.996477	valid_1's auc: 0.952389
# Did not meet early stopping. Best iteration is:
# [2000]	training's auc: 0.996477	valid_1's auc: 0.952389
# Fold: 4
# 531486 59054
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.930575	valid_1's auc: 0.918853
# [400]	training's auc: 0.954563	valid_1's auc: 0.93503
# [600]	training's auc: 0.971219	valid_1's auc: 0.945551
# [800]	training's auc: 0.980654	valid_1's auc: 0.950682
# [1000]	training's auc: 0.986395	valid_1's auc: 0.953689
# [1200]	training's auc: 0.990159	valid_1's auc: 0.955506
# [1400]	training's auc: 0.992545	valid_1's auc: 0.956699
# [1600]	training's auc: 0.994092	valid_1's auc: 0.957519
# [1800]	training's auc: 0.995167	valid_1's auc: 0.957887
# [2000]	training's auc: 0.996069	valid_1's auc: 0.958136
# Did not meet early stopping. Best iteration is:
# [2000]	training's auc: 0.996069	valid_1's auc: 0.958136
# Fold: 5
# 531486 59054
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.933085	valid_1's auc: 0.884005
# [400]	training's auc: 0.956882	valid_1's auc: 0.903017
# [600]	training's auc: 0.972224	valid_1's auc: 0.914212
# [800]	training's auc: 0.981736	valid_1's auc: 0.921318
# [1000]	training's auc: 0.987199	valid_1's auc: 0.925049
# [1200]	training's auc: 0.990811	valid_1's auc: 0.926683
# [1400]	training's auc: 0.99315	valid_1's auc: 0.927899
# [1600]	training's auc: 0.994684	valid_1's auc: 0.928693
# [1800]	training's auc: 0.995772	valid_1's auc: 0.929302
# [2000]	training's auc: 0.996549	valid_1's auc: 0.929752
# Did not meet early stopping. Best iteration is:
# [2000]	training's auc: 0.996549	valid_1's auc: 0.929752
# Fold: 6
# 531486 59054
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.929631	valid_1's auc: 0.918344
# [400]	training's auc: 0.955613	valid_1's auc: 0.932847
# [600]	training's auc: 0.971575	valid_1's auc: 0.942738
# [800]	training's auc: 0.981227	valid_1's auc: 0.948697
# [1000]	training's auc: 0.986947	valid_1's auc: 0.952221
# [1200]	training's auc: 0.990676	valid_1's auc: 0.953904
# [1400]	training's auc: 0.993117	valid_1's auc: 0.954782
# [1600]	training's auc: 0.994685	valid_1's auc: 0.955342
# [1800]	training's auc: 0.995744	valid_1's auc: 0.955541
# [2000]	training's auc: 0.996511	valid_1's auc: 0.955716
# Did not meet early stopping. Best iteration is:
# [2000]	training's auc: 0.996511	valid_1's auc: 0.955716
# Fold: 7
# 531486 59054
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.929728	valid_1's auc: 0.913695
# [400]	training's auc: 0.953336	valid_1's auc: 0.932406
# [600]	training's auc: 0.970396	valid_1's auc: 0.945197
# [800]	training's auc: 0.980142	valid_1's auc: 0.95311
# [1000]	training's auc: 0.986052	valid_1's auc: 0.957011
# [1200]	training's auc: 0.989943	valid_1's auc: 0.95917
# [1400]	training's auc: 0.992522	valid_1's auc: 0.960383
# [1600]	training's auc: 0.994172	valid_1's auc: 0.961351
# [1800]	training's auc: 0.99527	valid_1's auc: 0.961846
# [2000]	training's auc: 0.996109	valid_1's auc: 0.962246
# Did not meet early stopping. Best iteration is:
# [2000]	training's auc: 0.996109	valid_1's auc: 0.962246
# Fold: 8
# 531486 59054
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.931409	valid_1's auc: 0.893969
# [400]	training's auc: 0.954997	valid_1's auc: 0.915314
# [600]	training's auc: 0.970653	valid_1's auc: 0.929221
# [800]	training's auc: 0.980727	valid_1's auc: 0.937881
# [1000]	training's auc: 0.986605	valid_1's auc: 0.942446
# [1200]	training's auc: 0.990353	valid_1's auc: 0.945452
# [1400]	training's auc: 0.992702	valid_1's auc: 0.947228
# [1600]	training's auc: 0.994331	valid_1's auc: 0.948453
# [1800]	training's auc: 0.995453	valid_1's auc: 0.949086
# [2000]	training's auc: 0.996293	valid_1's auc: 0.949571
# Did not meet early stopping. Best iteration is:
# [2000]	training's auc: 0.996293	valid_1's auc: 0.949571
# Fold: 9
# 531486 59054
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.929572	valid_1's auc: 0.902622
# [400]	training's auc: 0.955206	valid_1's auc: 0.917748
# [600]	training's auc: 0.971573	valid_1's auc: 0.929962
# [800]	training's auc: 0.981135	valid_1's auc: 0.937209
# [1000]	training's auc: 0.986827	valid_1's auc: 0.940256
# [1200]	training's auc: 0.99054	valid_1's auc: 0.94166
# [1400]	training's auc: 0.992893	valid_1's auc: 0.941743
# Early stopping, best iteration is:
# [1358]	training's auc: 0.992488	valid_1's auc: 0.941837

# %%
########################### Export
if not LOCAL_TEST:
    test_predictions['isFraud'] = test_predictions['prediction']
    test_predictions[['TransactionID','isFraud']].to_csv('../submissions/submission_2_2.csv', index=False)
